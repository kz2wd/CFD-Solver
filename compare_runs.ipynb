# %%
import numpy as np
import napari

run_em4 = np.linalg.norm(np.load("runs/200_1e-4_50.npy", mmap_mode="r"), axis=3)
run_em5 = np.linalg.norm(np.load("runs/200_1e-5_50.npy", mmap_mode="r"), axis=3)
print(run_em4.shape)
print(run_em5.shape)
# Out:
# (50, 32, 32)
# (50, 32, 32)

# %%
# %gui qt6
viewer = napari.Viewer()
viewer.add_image(run_em4, name="e4")
viewer.add_image(run_em5, name="e5")
# Out:
# <Image layer 'e5' at 0x715df42d75c0>
